# %%
import pandas as pd

# crear un DataFrame de ejemplo
data = {'belongs_to_collection': ["{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}",
                                  "{'id': 119050, 'name': 'Grumpy Old Men Collection', 'poster_path': '/81w8XDvNKuSkY84LhCj3i4LumFY.jpg', 'backdrop_path': '/6Y9fl8tD1xtyUrOHV2MkCYTpzgi.jpg'}",
                                  "{'id': None, 'name': 'null', 'poster_path': 'null', 'backdrop_path': 'null'}",
                                  "{'id': 96871, 'name': None, 'poster_path': '/e64sOI48hQXyru7naBFyssKFxVd.jpg', 'backdrop_path': 1}"],
        }

df1 = pd.DataFrame(data)

# definir una función lambda para extraer las columnas
extract_collection = lambda x: pd.Series(eval(x) if isinstance(x, str) else None)

# aplicar la función lambda y agregar las nuevas columnas
df1[['id', 'name', 'poster_path', 'backdrop_path']] = df1['belongs_to_collection'].apply(extract_collection)

# mostrar el resultado
print(df1)
# Out:
#                                belongs_to_collection        id  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...   10194.0
# 1  {'id': 119050, 'name': 'Grumpy Old Men Collect...  119050.0
# 2  {'id': None, 'name': 'null', 'poster_path': 'n...       NaN
# 3  {'id': 96871, 'name': None, 'poster_path': '/e...   96871.0
#
#                         name                       poster_path  \
# 0       Toy Story Collection  /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg
# 1  Grumpy Old Men Collection  /81w8XDvNKuSkY84LhCj3i4LumFY.jpg
# 2                       null                              null
# 3                       None  /e64sOI48hQXyru7naBFyssKFxVd.jpg
#
#                       backdrop_path
# 0  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg
# 1  /6Y9fl8tD1xtyUrOHV2MkCYTpzgi.jpg
# 2                              null
# 3                                 1

# %%
df1
# Out:
#                                belongs_to_collection        id  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...   10194.0
# 1  {'id': 119050, 'name': 'Grumpy Old Men Collect...  119050.0
# 2  {'id': None, 'name': 'null', 'poster_path': 'n...       NaN
# 3  {'id': 96871, 'name': None, 'poster_path': '/e...   96871.0
#
#                         name                       poster_path  \
# 0       Toy Story Collection  /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg
# 1  Grumpy Old Men Collection  /81w8XDvNKuSkY84LhCj3i4LumFY.jpg
# 2                       null                              null
# 3                       None  /e64sOI48hQXyru7naBFyssKFxVd.jpg
#
#                       backdrop_path
# 0  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg
# 1  /6Y9fl8tD1xtyUrOHV2MkCYTpzgi.jpg
# 2                              null
# 3                                 1

# %%
import pandas as pd
import json

df = pd.read_csv("E:\hENRYDATASEMANAS\lab1\movies_dataset.csv")
# Out:
# C:\Users\tonto\AppData\Local\Temp\ipykernel_18032\2449907559.py:4: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("E:\hENRYDATASEMANAS\lab1\movies_dataset.csv")

# %%
df["belongs_to_collection"].fillna( "{'id': None, 'name': None, 'poster_path': None, 'backdrop_path': None}", inplace=True)

# %%
df1= pd.DataFrame(df['belongs_to_collection'])

# %%
df1
# Out:
#                                    belongs_to_collection
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...
# 1      {'id': None, 'name': None, 'poster_path': None...
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3      {'id': None, 'name': None, 'poster_path': None...
# 4      {'id': 96871, 'name': 'Father of the Bride Col...
# ...                                                  ...
# 45461  {'id': None, 'name': None, 'poster_path': None...
# 45462  {'id': None, 'name': None, 'poster_path': None...
# 45463  {'id': None, 'name': None, 'poster_path': None...
# 45464  {'id': None, 'name': None, 'poster_path': None...
# 45465  {'id': None, 'name': None, 'poster_path': None...
#
# [45466 rows x 1 columns]

# %%
import pandas as pd

# crear un DataFrame de ejemplo
df2 = pd.DataFrame({'belongs_to_collection': ["{'id': None, 'name': None, 'poster_path': None, 'backdrop_path': None}"]})
df2
# Out:
#                                belongs_to_collection
# 0  {'id': None, 'name': None, 'poster_path': None...

# %%
for index, cell_value in df1['belongs_to_collection'].iteritems():
    # Verificamos el tipo de la celda
    cell_type = type(cell_value)
    print(f"El tipo de la celda en la fila {index} es {cell_type}.")
# Out:
# El tipo de la celda en la fila 0 es <class 'str'>.
# El tipo de la celda en la fila 1 es <class 'str'>.
# El tipo de la celda en la fila 2 es <class 'str'>.
# El tipo de la celda en la fila 3 es <class 'str'>.
# El tipo de la celda en la fila 4 es <class 'str'>.
# El tipo de la celda en la fila 5 es <class 'str'>.
# El tipo de la celda en la fila 6 es <class 'str'>.
# El tipo de la celda en la fila 7 es <class 'str'>.
# El tipo de la celda en la fila 8 es <class 'str'>.
# El tipo de la celda en la fila 9 es <class 'str'>.
# El tipo de la celda en la fila 10 es <class 'str'>.
# El tipo de la celda en la fila 11 es <class 'str'>.
# El tipo de la celda en la fila 12 es <class 'str'>.
# El tipo de la celda en la fila 13 es <class 'str'>.
# El tipo de la celda en la fila 14 es <class 'str'>.
# El tipo de la celda en la fila 15 es <class 'str'>.
# El tipo de la celda en la fila 16 es <class 'str'>.
# El tipo de la celda en la fila 17 es <class 'str'>.
# ...

# %%
counts = df1['belongs_to_collection'].apply(type).value_counts()

print(counts)
# Out:
# <class 'str'>    45466
# Name: belongs_to_collection, dtype: int64

# %%
import re

# %%
# Función para dividir la cadena en columnas
def split_collection(collection_str):
    try:
        # Función para dividir la cadena en columnas
        collection_dict = ast.literal_eval(collection_str)
        # Extraer los valores correspondientes utilizando el método get()
        id = collection_dict.get('id')
        name = collection_dict.get('name')
        poster_path = collection_dict.get('poster_path')
        backdrop_path = collection_dict.get('backdrop_path')
        return pd.Series([id, name, poster_path, backdrop_path])
    except:
        return pd.Series([None, None, None, None])

# Aplicar la función a la columna y agregar las nuevas columnas al DataFrame
df1[['id_collection', 'name_collection', 'poster_path_collection', 'backdrop_path_collection']] = df1['belongs_to_collection'].apply(split_collection)

# %%
df1.head(3)
# Out:
#                                belongs_to_collection  id_collection  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...        10194.0
# 1  {'id': None, 'name': None, 'poster_path': None...            NaN
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...       119050.0
#
#              name_collection            poster_path_collection  \
# 0       Toy Story Collection  /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg
# 1                       None                              None
# 2  Grumpy Old Men Collection  /nLvUdqgPgm3F85NMCii9gVFUcet.jpg
#
#            backdrop_path_collection
# 0  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg
# 1                              None
# 2  /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg

# %%
import pandas as pd
import ast
import numpy as np

# Crear DataFrame de ejemplo
df = pd.read_csv("E:\hENRYDATASEMANAS\lab1\movies_dataset.csv")
# Out:
# C:\Users\tonto\AppData\Local\Temp\ipykernel_18032\3838452829.py:6: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("E:\hENRYDATASEMANAS\lab1\movies_dataset.csv")

# %%
# Definir función para separar lista de diccionarios en dos columnas
def split_genres(row):
    # Convertir string a lista de diccionarios
    genres_list = ast.literal_eval(row)
    # Crear listas separadas para id y name
    id_list = [d.get('id') for d in genres_list]
    name_list = [d.get('name') for d in genres_list]
    # Crear diccionario de salida
    out_dict = {'id_Genres': id_list, 'name_Genres': name_list}
    return pd.Series(out_dict)

# Aplicar función a cada fila del DataFrame y agregar columnas resultantes
df[['id_Genres', 'name_Genres']] = df['genres'].apply(split_genres)

# %%
#Rellenamos los Nulos
df["production_companies"].fillna( "[{'name': 'sin dato', 'id': 'sin dato'}]", inplace=True)
# Definir función para separar lista de diccionarios en dos columnas
def split_production_companies(row):
   try:
        # Convertir string a lista de diccionarios
        production_companies_list = ast.literal_eval(row)
        # Crear listas separadas para id y name
        name_list = [d.get('name') for d in production_companies_list]
        id_list = [d.get('id') for d in production_companies_list]    
        # Crear diccionario de salida
        out_dict = {'name_production_companies': name_list, 'id_production_companies': id_list}
        return pd.Series(out_dict)
   except:
        salida = {'name_production_companies': None , 'id_production_companies': None}
        return pd.Series(salida)

# aplicar la función a la columna y agregar las nuevas columnas al DataFrame
df[['name_production_companies', 'id_production_companies']] = df['production_companies'].apply(split_production_companies)

# %%
#Rellenamos los Nulos
df["production_countries"].fillna( "[{ 'iso_3166_1': None,'name': None}]", inplace=True)
# Definir función para separar lista de diccionarios en dos columnas
def split_production_countries(row):
   try:
        # Convertir string a lista de diccionarios
        production_countries_list = ast.literal_eval(row)
        # Crear listas separadas para id y name
        iso_3166_1_list = [d.get('iso_3166_1') for d in production_countries_list] 
        name_list = [d.get('name') for d in production_countries_list]
           
        # Crear diccionario de salida
        out_dict = {'name_production_countries': name_list, 'iso_3166_1_production_countries': iso_3166_1_list}
        return pd.Series(out_dict)
   except:
        salida = {'name_production_countries': None , 'iso_3166_1_production_countries': None}
        return pd.Series(salida)

# aplicar la función a la columna y agregar las nuevas columnas al DataFrame
df[['name_production_countries', 'iso_3166_1_production_countries']] = df['production_countries'].apply(split_production_countries)

# %%
#Rellenamos los Nulos
df["spoken_languages"].fillna( "[{ 'iso_639_1': None,'name': None}]", inplace=True)
# Definir función para separar lista de diccionarios en dos columnas
def split_spoken_languages(row):
   try:
        # Convertir string a lista de diccionarios
        spoken_languages_list = ast.literal_eval(row)
        # Crear listas separadas para id y name
        iso_639_1_list = [d.get('iso_639_1') for d in spoken_languages_list] 
        name_list = [d.get('name') for d in spoken_languages_list]
           
        # Crear diccionario de salida
        out_dict = {'name_spoken_languages': name_list, 'iso_639_1_spoken_languages': iso_639_1_list}
        return pd.Series(out_dict)
   except:
        salida = {'name_spoken_languages': None , 'iso_639_1_spoken_languages': None}
        return pd.Series(salida)

# aplicar la función a la columna y agregar las nuevas columnas al DataFrame
df[['name_spoken_languages', 'iso_639_1_spoken_languages']] = df['spoken_languages'].apply(split_spoken_languages)

# %%
# contar los valores nulos en cada columna
null_counts = df.isnull().sum()

# imprimir el resultado
print(null_counts)
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
# Convertir columna release_date al formato deseado
df["release_date"] = pd.to_datetime(df["release_date"], format="%Y-%m-%d", errors="coerce")

# Extraer el año de la fecha y crear la columna release_year
df["release_year"] = df["release_date"].dt.year

# %%
df['revenue'].fillna(0, inplace=True)
df['budget'].fillna(0, inplace=True)

# %%
# Convertir la columna budget a valores numéricos  en position 19730 string "/ff9qCepilowshEtG2GYWwzt2bs4.jpg"  por lo que se usara errors
df["budget"] = pd.to_numeric(df["budget"], errors="coerce")
# Crear columna return
df["return"] = np.where((df["budget"]==0) | (df["revenue"]==0), 0, df["revenue"]/df["budget"])

# %%
import pandas as pd
# Crear DataFrame de ejemplo
df = pd.read_csv("E:\hENRYDATASEMANAS\lab1\movies_dataset_modificado.csv")
# Out:
# C:\Users\tonto\AppData\Local\Temp\ipykernel_17656\1658208732.py:3: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("E:\hENRYDATASEMANAS\lab1\movies_dataset_modificado.csv")

# %%
df["id"].value_counts()
# Out:
# 141971    3
# 168538    2
# 25541     2
# 15028     2
# 11115     2
#          ..
# 72272     1
# 1549      1
# 10171     1
# 38996     1
# 461257    1
# Name: id, Length: 45436, dtype: int64
